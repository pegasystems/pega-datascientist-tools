# %%
import sys
import os

import pandas as pd
import numpy as np

from model_report import ADMReport, ModelReport
from cdh_utils import readDSExport
# Out:
# C:\Users\shiss\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df1 = readDSExport("Data-Decision-ADM-ModelSnapshot_pyModelSnapshots_20191120T113357_GMT.zip", srcFolder="../extra/example_reports_dmsample")
df2 = readDSExport("Data-Decision-ADM-PredictorBinningSnapshot_pyADMPredictorSnapshots_20191120T113436_GMT.zip", srcFolder="../extra/example_reports_dmsample")
# Out:
# Data-Decision-ADM-ModelSnapshot_pyModelSnapshots_20191120T113357_GMT.zip
# Data-Decision-ADM-PredictorBinningSnapshot_pyADMPredictorSnapshots_20191120T113436_GMT.zip

# %%
df1['pySnapshotTime'] = pd.to_datetime(df1['pySnapshotTime'])

# %%
df1.head(3)
# Out:
#                       pyAppliesToClass                   pySnapshotTime  \
# 0  DMOrg-DMSample-Work-MortgageRequest 2019-05-27 13:37:13.618000+00:00
# 1  DMOrg-DMSample-Work-MortgageRequest 2019-05-27 13:37:23.202000+00:00
# 2  DMOrg-DMSample-Work-MortgageRequest 2019-05-28 05:25:04.579000+00:00
#
#                               pyModelID  \
# 0  0036c6b6-b9ea-512d-9ed7-fa21274b284c
# 1  0036c6b6-b9ea-512d-9ed7-fa21274b284c
# 2  0036c6b6-b9ea-512d-9ed7-fa21274b284c
#
#                                            pxInsName           pxSaveDateTime  \
# 0  0036C6B6-B9EA-512D-9ED7-FA21274B284C!20190527T...  20190527T133713.628 GMT
# 1  0036C6B6-B9EA-512D-9ED7-FA21274B284C!20190527T...  20190527T133742.792 GMT
# 2  0036C6B6-B9EA-512D-9ED7-FA21274B284C!20190528T...  20190528T052522.522 GMT
#
#    pyRelativePositives  pyNegatives  pyRelativeResponseCount  \
# 0                    0           63                        0
# 1                    0           63                        0
# 2                    0           63                        0
#
#    pyActivePredictors  pyPositives  ... pyConfigurationName  \
# 0                   7          187  ...      Adm_1559077670
# 1                   7          187  ...      Adm_1559077670
# 2                   5          187  ...      Adm_1559077670
#
#    pyPerformanceError pyResponseCount  pyRelativeNegatives  \
# 0              0.0017             250                    0
# 1              0.0017             250                    0
# 2              0.0017             250                    0
#
#                           pyName         pxCommitDateTime  pyChannel  \
# 0  {"pyStageName":"LoanClosing"}  20190527T133713.651 GMT        NaN
# 1  {"pyStageName":"LoanClosing"}  20190527T133742.815 GMT        NaN
# 2  {"pyStageName":"LoanClosing"}  20190528T052522.542 GMT        NaN
#
#    pyDirection pyGroup pyIssue
# 0          NaN     NaN     NaN
# 1          NaN     NaN     NaN
# 2          NaN     NaN     NaN
#
# [3 rows x 24 columns]

# %%
df2.head(3)
# Out:
#    pyBinResponseCountPercentage            pyContents  pyZRatio  \
# 0                           6.8  Range : [-0.42, 3.0] -0.892738
# 1                          10.4  Range : [-0.42, 3.0] -1.063584
# 2                          40.4  Range : [-0.42, 3.0] -1.335967
#
#                               pyModelID  pyRelativePositives     pyBinType  \
# 0  0036c6b6-b9ea-512d-9ed7-fa21274b284c                    0  EQUIBEHAVIOR
# 1  0036c6b6-b9ea-512d-9ed7-fa21274b284c                    0  EQUIBEHAVIOR
# 2  0036c6b6-b9ea-512d-9ed7-fa21274b284c                    0  EQUIBEHAVIOR
#
#    pyRelativeResponseCount   pyBinSymbol pyPredictorName  \
# 0                        0          <0.0      Classifier
# 1                        0   [0.0, 0.12>      Classifier
# 2                        0  [0.12, 0.53>      Classifier
#
#    pyBinPositivesPercentage  ...  pyNegatives  pyPositives  pyEntryType  \
# 0                      5.88  ...           63          187   Classifier
# 1                      9.09  ...           63          187   Classifier
# 2                     37.97  ...           63          187   Classifier
#
#   pyGroupIndex                                           pzInsKey  \
# 0            0  DATA-DECISION-ADM-PREDICTORBINNINGSNAPSHOT 003...
# 1            0  DATA-DECISION-ADM-PREDICTORBINNINGSNAPSHOT 003...
# 2            0  DATA-DECISION-ADM-PREDICTORBINNINGSNAPSHOT 003...
#
#    pyBinPositives  pyRelativeBinNegatives  pyRelativeNegatives  \
# 0              11                       0                    0
# 1              17                       0                    0
# 2              71                       0                    0
#
#    pyBinResponseCount         pxCommitDateTime
# 0                  17  20190527T133713.651 GMT
# 1                  26  20190527T133713.651 GMT
# 2                 101  20190527T133713.651 GMT
#
# [3 rows x 36 columns]

# %% [markdown]
# Create a ModelReport class instance called Models. To instantiate the class, use the parameters listed in the example below. Different reports, depending on how they are extracted, might have different column names. The class instance ensures that any file regardless of column name can be used.

# %%
Models = ModelReport(np.array(df1['pyModelID']), np.array(df1['pyName']), 
                     np.array(df1['pyPositives']), np.array(df1['pyResponseCount']), 
                     np.array(df1['pyPerformance']), np.array(df1['pySnapshotTime']))

# %% [markdown]
# ## Graph that shows the success rate of the latest model snapshot per model
#
# Since there are many models, figsize parameter has been used to modify the figure size

# %%
Models.show_success_rate(figsize=(12, 18))

# %% [markdown]
# In the above graph it is possible to show certain models instead of all models. query parameter is a dict type used for customization/filtering. The keys of the dict are properties that need to be customized/filtered. The value is of list type used as valid values for the corresponding key. In the following graph, query parameter is used to set 'model name' to those model names within Service group.

# %%
Models.show_success_rate(query={'model name':list(df1[df1['pyGroup']=='Service']['pyName'].unique())}, figsize=(10, 5))

# %% [markdown]
# ## Graph that shows response and AUC over time
#
# Use query parameter to customize the graph. The following graph focuses on the offers within Sales issue.

# %%
Models.show_response_auc_time(query={'model name':list(df1[df1['pyGroup']=='Sales']['pyName'].unique())}, 
                              figsize=(16, 8))
# Out:
# Maximum AUC across all models: 0.94

# %% [markdown]
# ## Bubble chart
#
# The following graph shows the bubble chart as shown on the Pega out-of-the-box model report landing page. Again, since the models are too many, it can be customized to focus on certain models of interest.

# %%
Models.show_bubble_chart()

# %%
Models.show_bubble_chart(query={'model name':list(df1[df1['pyGroup']=='Sales']['pyName'].unique())})

# %% [markdown]
# The below graph provides a calendar view of responses collected per offer over time. Each cell has the number of the responses per day. The color of each cell represent the change of responses compared to the previous day. If responses in a certain day increase compared to the previous timestamp, the cell will be white, if the responses do not change, then it will be shown by orange color. If this situation occurs very frequently for a certain model, or if it continues over time, the model might need attention to understand why it is not being offered. Lastly, if the responses decrease, that will be labeled by red. This should not happen at all.

# %%
Models.show_calendar_heatmap(query={'model name':list(df1[df1['pyGroup']=='Sales']['pyName'].unique())},
                             fill_null_days=False, lookback=90)

# %% [markdown]
# # Explore Predictor Report

# %% [markdown]
# First instantiate the preditor class. Use the following code as an example:

# %%
Preds = ADMReport(Models.modelID, Models.modelName, Models.positives, Models.responses, Models.modelAUC, 
                  Models.modelSnapshot, np.array(df2['pyModelID']), np.array(df2['pyPredictorName']), 
                  np.array(df2['pyPerformance']), np.array(df2['pyBinSymbol']), 
                  np.array(df2['pyBinIndex']), np.array(df2['pyEntryType']), 
                  np.array(df2['pyType']), np.array(df2['pySnapshotTime']), 
                  np.array(df2['pyBinPositives']), np.array(df2['pyBinResponseCount']))

# %% [markdown]
# ## Showing score distributions within Sales group

# %%
Preds.show_score_distribution(models=list(df1[df1['pyGroup']=='Sales']['pyName'].unique()), figsize=(12,5))

# %% [markdown]
# ## Showing predictor report for active predictors within 'Partner Card' model
#
# The model has numerous active predictors. Here we show the predictor graphs for a selection of predictors with highest performance

# %%
Preds.show_predictor_report('Partner Card', list(Preds.latestPredModel[
    (Preds.latestPredModel['model name']=='Partner Card') & 
    (Preds.latestPredModel['entry type']=='Active')].sort_values(
    'predictor performance', ascending=False)['predictor name'].unique()[0:6]))

# %% [markdown]
# Show a boxplot of predictor performance accross all models in Sales group

# %%
Preds.show_predictor_performance_boxplot(query={'model name':list(
    df1[df1['pyGroup']=='Tablets']['pyName'].unique())}, figsize=(10, 14))

# %%
Preds.show_model_predictor_performance_heatmap(query={'model name':list(
    df1[df1['pyGroup']=='Tablets']['pyName'].unique())}, figsize=(17, 13))
