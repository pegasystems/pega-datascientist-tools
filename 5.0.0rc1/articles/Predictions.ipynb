# %% [markdown]
# > **📦 Optional dependencies**
# >
# > This article uses features from the pdstools `adm` extra. Install with your favorite package manager, e.g. `uv pip install "pdstools[adm]"`.

# %%
# --- IGNORE ---
import plotly.io as pio

pio.renderers.default = "notebook_connected"

# %% [markdown]
# # Example Prediction Studio Analysis
#
# __Pega__
#
# __2025-07-04__
#
# This is a small notebook to report and analyse Prediction Studio data on Predictions. The underlying data is from the Data-DM-Snapshot table that is used to populate the Prediction Studio screen with Prediction Performance, Lift, CTR etc.
#
# Data can be exported from the **pyGetSnapshot** dataset in Pega Infinity from Dev Studio and Prediction Studio.
#
# Datamart tables are described [here](https://docs.pega.com/bundle/platform/page/platform/decision-management/database-tables-monitoring-models.html).

# %% [markdown]
# ## Raw data
#
# First, we're going to load the raw data. The raw data is in a "long" format with e.g. test and control groups in separate rows.

# %%
from pathlib import Path
from pdstools import Prediction

# path to dataset export here
# e.g. PR_DATA_DM_SNAPSHOTS.parquet
data_export = "<YOUR DATA HERE>"

if Path(data_export).exists():
    prediction = Prediction.from_ds_export(data_export)
else:
    prediction = Prediction.from_mock_data(days=60)

# %% [markdown]
# ## Prediction Data
#
# The actual prediction data is in a "wide" format with separate fields for Test and Control groups. Also, it is only the "daily" snapshots and the numbers and date are formatted to be normal Polars types.

# %%
prediction.predictions.head().collect()
# Out:
# shape: (5, 23)
# ┌────────────┬────────────┬───────────┬───────────┬───┬───────────┬─────────┬──────────┬───────────┐
# │ pyModelId  ┆ SnapshotTi ┆ Positives ┆ Negatives ┆ … ┆ CTR_Contr ┆ CTR_NBA ┆ CTR_Lift ┆ isValidPr │
# │ ---        ┆ me         ┆ ---       ┆ ---       ┆   ┆ ol        ┆ ---     ┆ ---      ┆ ediction  │
# │ str        ┆ ---        ┆ f64       ┆ i64       ┆   ┆ ---       ┆ f64     ┆ f64      ┆ ---       │
# │            ┆ date       ┆           ┆           ┆   ┆ f64       ┆         ┆          ┆ bool      │
# ╞════════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═════════╪══════════╪═══════════╡
# │ DATA-DECIS ┆ 2026-04-28 ┆ 150.0     ┆ 6000      ┆ … ┆ 0.019608  ┆ 0.02439 ┆ 1.04     ┆ true      │
# │ ION-REQUES ┆            ┆           ┆           ┆   ┆           ┆         ┆          ┆           │
# │ T-CUSTOMER ┆            ┆           ┆           ┆   ┆           ┆         ┆          ┆           │
# │ …          ┆            ┆           ┆           ┆   ┆           ┆         ┆          ┆           │
# │ DATA-DECIS ┆ 2026-04-28 ┆ 250.0     ┆ 6000      ┆ … ┆ 0.019608  ┆ 0.02439 ┆ 1.04     ┆ true      │
# │ ION-REQUES ┆            ┆           ┆           ┆   ┆           ┆         ┆          ┆           │
# │ T-CUSTOMER ┆            ┆           ┆           ┆   ┆           ┆         ┆          ┆           │
# │ …          ┆            ┆           ┆           ┆   ┆           ┆         ┆          ┆           │
# │ DATA-DECIS ┆ 2026-04-28 ┆ 120.0     ┆ 6000      ┆ … ┆ 0.019608  ┆ 0.02439 ┆ 1.04     ┆ true      │
# │ ION-REQUES ┆            ┆           ┆           ┆   ┆           ┆         ┆          ┆           │
# │ T-CUSTOMER ┆            ┆           ┆           ┆   ┆           ┆         ┆          ┆           │
# │ …          ┆            ┆           ┆           ┆   ┆           ┆         ┆          ┆           │
# │ DATA-DECIS ┆ 2026-04-29 ┆ 120.0     ┆ 6000      ┆ … ┆ 0.019608  ┆ 0.02439 ┆ 1.046638 ┆ true      │
# │ ION-REQUES ┆            ┆           ┆           ┆   ┆           ┆         ┆          ┆           │
# │ T-CUSTOMER ┆            ┆           ┆           ┆   ┆           ┆         ┆          ┆           │
# │ …          ┆            ┆           ┆           ┆   ┆           ┆         ┆          ┆           │
# │ DATA-DECIS ┆ 2026-04-29 ┆ 250.84745 ┆ 6000      ┆ … ┆ 0.019608  ┆ 0.02439 ┆ 1.046638 ┆ true      │
# │ ION-REQUES ┆            ┆ 8         ┆           ┆   ┆           ┆         ┆          ┆           │
# │ T-CUSTOMER ┆            ┆           ┆           ┆   ┆           ┆         ┆          ┆           │
# │ …          ┆            ┆           ┆           ┆   ┆           ┆         ┆          ┆           │
# └────────────┴────────────┴───────────┴───────────┴───┴───────────┴─────────┴──────────┴───────────┘

# %% [markdown]
# ## Summary by Channel
#
# Standard functionality exists to summarize the predictions per channel. Note that we do not have the prediction to channel mapping in the data (this is an outstanding product issue), so apply the implicit naming conventions of NBAD. For a specific customer, custom mappings can be passed into the summarization function.

# %%
prediction.summary_by_channel().collect()
# Out:
# shape: (3, 28)
# ┌──────────────┬─────────┬───────────┬──────────┬───┬──────────┬──────────────┬─────────┬──────────┐
# │ Prediction   ┆ Channel ┆ Direction ┆ usesNBAD ┆ … ┆ CTR_NBA  ┆ ChannelDirec ┆ isValid ┆ Lift     │
# │ ---          ┆ ---     ┆ ---       ┆ ---      ┆   ┆ ---      ┆ tionGroup    ┆ ---     ┆ ---      │
# │ str          ┆ str     ┆ str       ┆ bool     ┆   ┆ f64      ┆ ---          ┆ bool    ┆ f64      │
# │              ┆         ┆           ┆          ┆   ┆          ┆ str          ┆         ┆          │
# ╞══════════════╪═════════╪═══════════╪══════════╪═══╪══════════╪══════════════╪═════════╪══════════╡
# │ PREDICTMOBIL ┆ Mobile  ┆ Inbound   ┆ true     ┆ … ┆ 0.02439  ┆ Mobile/Inbou ┆ true    ┆ 1.23506  │
# │ EPROPENSITY  ┆         ┆           ┆          ┆   ┆          ┆ nd           ┆         ┆          │
# │ PREDICTOUTBO ┆ E-mail  ┆ Outbound  ┆ true     ┆ … ┆ 0.011858 ┆ E-mail/Outbo ┆ true    ┆ 0.785855 │
# │ UNDEMAILPROP ┆         ┆           ┆          ┆   ┆          ┆ und          ┆         ┆          │
# │ ENSITY       ┆         ┆           ┆          ┆   ┆          ┆              ┆         ┆          │
# │ PREDICTWEBPR ┆ Web     ┆ Inbound   ┆ true     ┆ … ┆ 0.036609 ┆ Web/Inbound  ┆ true    ┆ 1.316656 │
# │ OPENSITY     ┆         ┆           ┆          ┆   ┆          ┆              ┆         ┆          │
# └──────────────┴─────────┴───────────┴──────────┴───┴──────────┴──────────────┴─────────┴──────────┘

# %% [markdown]
# ## Prediction Trends
#
# Summarization by default is over all time. You can pass in an argument to summarize by day, week or any other period as supported by the [Polars time offset string language](https://docs.pola.rs/api/python/stable/reference/expressions/api/polars.Expr.dt.offset_by.html).
#
# This trend data can then easily be visualized.

# %%
fig = prediction.plot.performance_trend("1w")
fig.show()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="eb8b62fe-b32c-446c-a532-0719b5fe0d29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("eb8b62fe-b32c-446c-a532-0719b5fe0d29")) {                    Plotly.newPlot(                        "eb8b62fe-b32c-446c-a532-0719b5fe0d29",                        [{"customdata":[["6 days",3132.7118644067796,108000,4538.135593220339,108000,0.04032531345306675,2160.0,108000,0.0196078431372549,2700.0,108000,0.024390243902439025],["7 days",3693.3898305084745,126000,5410.169491525424,126000,0.041170097508125676,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3734.915254237288,126000,5534.745762711865,126000,0.0420782032201326,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3776.4406779661017,126000,5659.322033898305,126000,0.042984590429845905,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3817.9661016949153,126000,5783.8983050847455,126000,0.043889264010803515,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3859.491525423729,126000,5908.474576271186,126000,0.04479222881813275,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3901.016949152542,126000,6033.050847457627,126000,0.04569348968863728,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3942.5423728813557,126000,6157.627118644068,126000,0.04659305144088338,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["5 days",2841.5254237288136,90000,4474.576271186441,90000,0.047362755651237896,1800.0,90000,0.0196078431372549,2250.0,90000,0.024390243902439025]],"hovertemplate":"Prediction=Mobile (PREDICTMOBILEPROPENSITY)\u003cbr\u003eDate=%{x}\u003cbr\u003ePerformance=%{y}\u003cbr\u003ePeriod=%{customdata[0]}\u003cbr\u003ePositives=%{customdata[1]}\u003cbr\u003eNegatives=%{customdata[2]}\u003cbr\u003ePositives_Test=%{customdata[3]}\u003cbr\u003eNegatives_Test=%{customdata[4]}\u003cbr\u003eCTR_Test=%{customdata[5]:.3%}\u003cbr\u003ePositives_Control=%{customdata[6]}\u003cbr\u003eNegatives_Control=%{customdata[7]}\u003cbr\u003eCTR_Control=%{customdata[8]:.3%}\u003cbr\u003ePositives_NBA=%{customdata[9]}\u003cbr\u003eNegatives_NBA=%{customdata[10]}\u003cbr\u003eCTR_NBA=%{customdata[11]:.3%}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mobile (PREDICTMOBILEPROPENSITY)","line":{"color":"#001F5F","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Mobile (PREDICTMOBILEPROPENSITY)","orientation":"v","showlegend":true,"x":["2026-04-28","2026-05-04","2026-05-11","2026-05-18","2026-05-25","2026-06-01","2026-06-08","2026-06-15","2026-06-22"],"xaxis":"x","y":[70.12712243239515,70.45763469203541,70.81356723158623,71.1694997708274,71.52543060700283,71.88136314617007,72.23729568572816,72.59322907651077,72.89830671955625],"yaxis":"y","type":"scatter"},{"customdata":[["6 days",2290.169491525424,180000,2910.508474576271,180000,0.015912199352837175,1800.0,180000,0.009900990099009901,2160.0,180000,0.011857707509881422],["7 days",2702.7118644067796,210000,3488.135593220339,210000,0.016338779593197735,2100.0,210000,0.009900990099009901,2520.0,210000,0.011857707509881422],["7 days",2735.9322033898306,210000,3587.7966101694915,210000,0.01679776029862685,2100.0,210000,0.009900990099009901,2520.0,210000,0.011857707509881422],["7 days",2769.1525423728813,210000,3687.4576271186443,210000,0.017256312878939303,2100.0,210000,0.009900990099009901,2520.0,210000,0.011857707509881422],["7 days",2802.3728813559323,210000,3787.1186440677966,210000,0.017714437932871606,2100.0,210000,0.009900990099009901,2520.0,210000,0.011857707509881422],["7 days",2835.59322 ...

# %%
fig = prediction.plot.lift_trend("1w")
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="823eba1d-cfd1-45d5-82b7-690f56681ce9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("823eba1d-cfd1-45d5-82b7-690f56681ce9")) {                    Plotly.newPlot(                        "823eba1d-cfd1-45d5-82b7-690f56681ce9",                        [{"customdata":[["6 days",3132.7118644067796,108000,4538.135593220339,108000,0.04032531345306675,2160.0,108000,0.0196078431372549,2700.0,108000,0.024390243902439025],["7 days",3693.3898305084745,126000,5410.169491525424,126000,0.041170097508125676,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3734.915254237288,126000,5534.745762711865,126000,0.0420782032201326,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3776.4406779661017,126000,5659.322033898305,126000,0.042984590429845905,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3817.9661016949153,126000,5783.8983050847455,126000,0.043889264010803515,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3859.491525423729,126000,5908.474576271186,126000,0.04479222881813275,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3901.016949152542,126000,6033.050847457627,126000,0.04569348968863728,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3942.5423728813557,126000,6157.627118644068,126000,0.04659305144088338,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["5 days",2841.5254237288136,90000,4474.576271186441,90000,0.047362755651237896,1800.0,90000,0.0196078431372549,2250.0,90000,0.024390243902439025]],"hovertemplate":"Prediction=Mobile (PREDICTMOBILEPROPENSITY)\u003cbr\u003eDate=%{x}\u003cbr\u003eLift=%{y}\u003cbr\u003ePeriod=%{customdata[0]}\u003cbr\u003ePositives=%{customdata[1]}\u003cbr\u003eNegatives=%{customdata[2]}\u003cbr\u003ePositives_Test=%{customdata[3]}\u003cbr\u003eNegatives_Test=%{customdata[4]}\u003cbr\u003eCTR_Test=%{customdata[5]:.3%}\u003cbr\u003ePositives_Control=%{customdata[6]}\u003cbr\u003eNegatives_Control=%{customdata[7]}\u003cbr\u003eCTR_Control=%{customdata[8]:.3%}\u003cbr\u003ePositives_NBA=%{customdata[9]}\u003cbr\u003eNegatives_NBA=%{customdata[10]}\u003cbr\u003eCTR_NBA=%{customdata[11]:.3%}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mobile (PREDICTMOBILEPROPENSITY)","line":{"color":"#001F5F","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Mobile (PREDICTMOBILEPROPENSITY)","orientation":"v","showlegend":true,"x":["2026-04-28","2026-05-04","2026-05-11","2026-05-18","2026-05-25","2026-06-01","2026-06-08","2026-06-15","2026-06-22"],"xaxis":"x","y":{"dtype":"f8","bdata":"1DQp88vn8D9rWs7IRJjxPy01H+X3VfI\u002fgpDIGk8T8z\u002fmrYKsStDzP85IxdzqjPQ\u002frOTH7S9J9T9WGoIhGgX2P2mIceTjpfY\u002f"},"yaxis":"y","type":"scatter"},{"customdata":[["6 days",2290.169491525424,180000,2910.508474576271,180000,0.015912199352837175,1800.0,180000,0.009900990099009901,2160.0,180000,0.011857707509881422],["7 days",2702.7118644067796,210000,3488.135593220339,210000,0.016338779593197735,2100.0,210000,0.009900990099009901,2520.0,210000,0.011857707509881422],["7 days",2735.9322033898306,210000,3587.7966101694915,210000,0.01679776029862685,2100.0,210000,0.009900990099009901,2520.0,210000,0.011857707509881422],["7 days",2769.1525423728813,210000,3687.4576271186443,210000,0.017256312878939303,2100.0,210000,0.009900990099009901,2520.0,210000,0.011857707509881422],["7 days",2802.3728813559323,210000,3787.1186440677966,210000,0.017714437932871606,2100.0,210000,0.009900990099009901,2520.0,210000,0.011857707509881422],["7 days",2835.593220338983,210000,3886.77966101 ...

# %%
fig = prediction.plot.ctr_trend("1w", facetting=False)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="5776b66c-56ff-4a5b-9d90-8437dc5ff62e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5776b66c-56ff-4a5b-9d90-8437dc5ff62e")) {                    Plotly.newPlot(                        "5776b66c-56ff-4a5b-9d90-8437dc5ff62e",                        [{"customdata":[["6 days",3132.7118644067796,108000,4538.135593220339,108000,0.04032531345306675,2160.0,108000,0.0196078431372549,2700.0,108000,0.024390243902439025],["7 days",3693.3898305084745,126000,5410.169491525424,126000,0.041170097508125676,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3734.915254237288,126000,5534.745762711865,126000,0.0420782032201326,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3776.4406779661017,126000,5659.322033898305,126000,0.042984590429845905,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3817.9661016949153,126000,5783.8983050847455,126000,0.043889264010803515,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3859.491525423729,126000,5908.474576271186,126000,0.04479222881813275,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3901.016949152542,126000,6033.050847457627,126000,0.04569348968863728,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3942.5423728813557,126000,6157.627118644068,126000,0.04659305144088338,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["5 days",2841.5254237288136,90000,4474.576271186441,90000,0.047362755651237896,1800.0,90000,0.0196078431372549,2250.0,90000,0.024390243902439025]],"hovertemplate":"Prediction=Mobile (PREDICTMOBILEPROPENSITY)\u003cbr\u003eDate=%{x}\u003cbr\u003eCTR=%{y}\u003cbr\u003ePeriod=%{customdata[0]}\u003cbr\u003ePositives=%{customdata[1]}\u003cbr\u003eNegatives=%{customdata[2]}\u003cbr\u003ePositives_Test=%{customdata[3]}\u003cbr\u003eNegatives_Test=%{customdata[4]}\u003cbr\u003eCTR_Test=%{customdata[5]:.3%}\u003cbr\u003ePositives_Control=%{customdata[6]}\u003cbr\u003eNegatives_Control=%{customdata[7]}\u003cbr\u003eCTR_Control=%{customdata[8]:.3%}\u003cbr\u003ePositives_NBA=%{customdata[9]}\u003cbr\u003eNegatives_NBA=%{customdata[10]}\u003cbr\u003eCTR_NBA=%{customdata[11]:.3%}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mobile (PREDICTMOBILEPROPENSITY)","line":{"color":"#001F5F","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Mobile (PREDICTMOBILEPROPENSITY)","orientation":"v","showlegend":true,"x":["2026-04-28","2026-05-04","2026-05-11","2026-05-18","2026-05-25","2026-06-01","2026-06-08","2026-06-15","2026-06-22"],"xaxis":"x","y":{"dtype":"f8","bdata":"MhZ62I7dnD9fE7GkTCmdPwnQ8RLRep0\u002frCRdJkjMnT8r8zrisR2eP2IK0kkOb54\u002fmyZoYF3Anj\u002f\u002f8UEpnxGfP8Gd6q46V58\u002f"},"yaxis":"y","type":"scatter"},{"customdata":[["6 days",2290.169491525424,180000,2910.508474576271,180000,0.015912199352837175,1800.0,180000,0.009900990099009901,2160.0,180000,0.011857707509881422],["7 days",2702.7118644067796,210000,3488.135593220339,210000,0.016338779593197735,2100.0,210000,0.009900990099009901,2520.0,210000,0.011857707509881422],["7 days",2735.9322033898306,210000,3587.7966101694915,210000,0.01679776029862685,2100.0,210000,0.009900990099009901,2520.0,210000,0.011857707509881422],["7 days",2769.1525423728813,210000,3687.4576271186443,210000,0.017256312878939303,2100.0,210000,0.009900990099009901,2520.0,210000,0.011857707509881422],["7 days",2802.3728813559323,210000,3787.1186440677966,210000,0.017714437932871606,2100.0,210000,0.009900990099009901,2520.0,210000,0.011857707509881422],["7 days",2835.593220338983,210000,3886.7796 ...

# %%
fig = prediction.plot.responsecount_trend("1w", facetting=False)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="88bbb078-c7de-4fac-85e8-346c7d3e8565" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("88bbb078-c7de-4fac-85e8-346c7d3e8565")) {                    Plotly.newPlot(                        "88bbb078-c7de-4fac-85e8-346c7d3e8565",                        [{"customdata":[["6 days",3132.7118644067796,108000,4538.135593220339,108000,0.04032531345306675,2160.0,108000,0.0196078431372549,2700.0,108000,0.024390243902439025],["7 days",3693.3898305084745,126000,5410.169491525424,126000,0.041170097508125676,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3734.915254237288,126000,5534.745762711865,126000,0.0420782032201326,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3776.4406779661017,126000,5659.322033898305,126000,0.042984590429845905,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3817.9661016949153,126000,5783.8983050847455,126000,0.043889264010803515,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3859.491525423729,126000,5908.474576271186,126000,0.04479222881813275,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3901.016949152542,126000,6033.050847457627,126000,0.04569348968863728,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["7 days",3942.5423728813557,126000,6157.627118644068,126000,0.04659305144088338,2520.0,126000,0.0196078431372549,3150.0,126000,0.024390243902439025],["5 days",2841.5254237288136,90000,4474.576271186441,90000,0.047362755651237896,1800.0,90000,0.0196078431372549,2250.0,90000,0.024390243902439025]],"hovertemplate":"Prediction=Mobile (PREDICTMOBILEPROPENSITY)\u003cbr\u003eDate=%{x}\u003cbr\u003eResponses=%{y}\u003cbr\u003ePeriod=%{customdata[0]}\u003cbr\u003ePositives=%{customdata[1]}\u003cbr\u003eNegatives=%{customdata[2]}\u003cbr\u003ePositives_Test=%{customdata[3]}\u003cbr\u003eNegatives_Test=%{customdata[4]}\u003cbr\u003eCTR_Test=%{customdata[5]:.3%}\u003cbr\u003ePositives_Control=%{customdata[6]}\u003cbr\u003eNegatives_Control=%{customdata[7]}\u003cbr\u003eCTR_Control=%{customdata[8]:.3%}\u003cbr\u003ePositives_NBA=%{customdata[9]}\u003cbr\u003eNegatives_NBA=%{customdata[10]}\u003cbr\u003eCTR_NBA=%{customdata[11]:.3%}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mobile (PREDICTMOBILEPROPENSITY)","line":{"color":"#001F5F","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"Mobile (PREDICTMOBILEPROPENSITY)","orientation":"v","showlegend":true,"x":["2026-04-28","2026-05-04","2026-05-11","2026-05-18","2026-05-25","2026-06-01","2026-06-08","2026-06-15","2026-06-22"],"xaxis":"x","y":{"dtype":"f8","bdata":"pe7LY8sh+0BO6r481qn\u002fQIug4aRurP9AyFYEDQev\u002f0AEDSd1n7H\u002fQEHDSd03tP9AfnlsRdC2\u002f0C7L4+taLn\u002fQD22ImiYqvZA"},"yaxis":"y","type":"scatter"},{"customdata":[["6 days",2290.169491525424,180000,2910.508474576271,180000,0.015912199352837175,1800.0,180000,0.009900990099009901,2160.0,180000,0.011857707509881422],["7 days",2702.7118644067796,210000,3488.135593220339,210000,0.016338779593197735,2100.0,210000,0.009900990099009901,2520.0,210000,0.011857707509881422],["7 days",2735.9322033898306,210000,3587.7966101694915,210000,0.01679776029862685,2100.0,210000,0.009900990099009901,2520.0,210000,0.011857707509881422],["7 days",2769.1525423728813,210000,3687.4576271186443,210000,0.017256312878939303,2100.0,210000,0.009900990099009901,2520.0,210000,0.011857707509881422],["7 days",2802.3728813559323,210000,3787.1186440677966,210000,0.017714437932871606,2100.0,210000,0.009900990099009901,2520.0,210000,0.011857707509881422],["7 days",2835.593220338983,210000,388 ...
