# %% [markdown]
# # Explainability Extract Analysis
#
# This notebook demonstrates the `DecisionAnalyzer` class from pdstools using the Explainability Extract v1 dataset.
#
# The Explainability Extract captures actions at the **Arbitration** stage only. It can be extracted from Infinity 24.1 and earlier versions. For the full decision funnel (v2 format), see the [Decision Analyzer notebook](../decision_analyzer/decision_analyzer.ipynb).
#
# The analyses below cover action distribution, sensitivity, win/loss patterns, and personalization.

# %%
# These lines are only for rendering in the docs, and are hidden through Jupyter tags
# Do not run if you're running the notebook seperately

import plotly.io as pio

pio.renderers.default = "notebook_connected"

# %%
from pdstools.pega_io import read_data
from pdstools.decision_analyzer.DecisionAnalyzer import DecisionAnalyzer
from pdstools import read_ds_export
import polars as pl

# %% [markdown]
# ### Read Data
#
# Load the sample Explainability Extract data and create a `DecisionAnalyzer` instance. The sample data can be downloaded directly from [GitHub](https://github.com/pegasystems/pega-datascientist-tools/raw/master/data/sample_explainability_extract.parquet).

# %%
df = read_ds_export(
    filename="sample_explainability_extract.parquet",
    path="https://raw.githubusercontent.com/pegasystems/pega-datascientist-tools/master/data",
)
decision_data = DecisionAnalyzer(df)

# %%
decision_data.decision_data.collect()
# Out:
# shape: (7_297, 21)
# ┌─────────────┬─────────────┬────────────┬────────────┬───┬──────┬────────────┬───────┬────────────┐
# │ Subject ID  ┆ Interaction ┆ Decision   ┆ Issue      ┆ … ┆ Rank ┆ Stage      ┆ Stage ┆ Record     │
# │ ---         ┆ ID          ┆ Time       ┆ ---        ┆   ┆ ---  ┆ Group      ┆ Order ┆ Type       │
# │ str         ┆ ---         ┆ ---        ┆ str        ┆   ┆ u64  ┆ ---        ┆ ---   ┆ ---        │
# │             ┆ str         ┆ datetime[μ ┆            ┆   ┆      ┆ cat        ┆ i32   ┆ str        │
# │             ┆             ┆ s]         ┆            ┆   ┆      ┆            ┆       ┆            │
# ╞═════════════╪═════════════╪════════════╪════════════╪═══╪══════╪════════════╪═══════╪════════════╡
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-17 ┆ Retention  ┆ … ┆ 25   ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _466        ┆ 720831070   ┆ 18:21:40.2 ┆            ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-17 ┆ Retention  ┆ … ┆ 3    ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _466        ┆ 720831070   ┆ 18:21:40.2 ┆            ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-17 ┆ Retention  ┆ … ┆ 41   ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _466        ┆ 720831070   ┆ 18:21:40.2 ┆            ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-17 ┆ Retention  ┆ … ┆ 54   ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _466        ┆ 720831070   ┆ 18:21:40.2 ┆            ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-17 ┆ Acquisitio ┆ … ┆ 40   ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _466        ┆ 720831070   ┆ 18:21:40.2 ┆ n          ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ …           ┆ …           ┆ …          ┆ …          ┆ … ┆ …    ┆ …          ┆ …     ┆ …          │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-15 ┆ Engagement ┆ … ┆ 62   ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _1748       ┆ 720840506   ┆ 18:21:40.2 ┆            ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-15 ┆ Retention  ┆ … ┆ 12   ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _1748       ┆ 720840506   ┆ 18:21:40.2 ┆            ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-15 ┆ Retention  ┆ … ┆ 8    ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _1748       ┆ 720840506   ┆ 18:21:40.2 ┆            ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-15 ┆ Retention  ┆ … ┆ 5    ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _1748       ┆ 720840506   ┆ 18:21:40.2 ┆            ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-15 ┆ Engagement ┆ … ┆ 40   ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _1748       ┆ 720840506   ┆ 18:21:40.2 ┆            ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# └─────────────┴─────────────┴────────────┴────────────┴───┴──────┴────────────┴───────┴────────────┘

# %% [markdown]
# ### Overview

# %% [markdown]
# General statistics of the dataset.

# %%
decision_data.overview_stats
# Out:
# {'Actions': 152,
#  'Channels': 1,
#  'Duration': datetime.timedelta(days=7),
#  'StartDate': datetime.date(2024, 6, 12),
#  'Customers': 100,
#  'Decisions': 100,
#  'avgOffersAtArbitration': 73,
#  'avgAvailable': 0}

# %% [markdown]
# A single decision. The number of rows shows how many actions are available at the Arbitration stage. `Rank` shows the action ranking.

# %%
selected_interaction_id = (
    decision_data.decision_data.select("Interaction ID")
    .first()
    .collect()
    .row(0)[0]
)
print(f"{selected_interaction_id=}")
decision_data.decision_data.filter(
    pl.col("Interaction ID") == selected_interaction_id
).sort("Rank").collect()
# Out:
# selected_interaction_id='-8570391784720831070'
# shape: (72, 21)
# ┌─────────────┬─────────────┬────────────┬────────────┬───┬──────┬────────────┬───────┬────────────┐
# │ Subject ID  ┆ Interaction ┆ Decision   ┆ Issue      ┆ … ┆ Rank ┆ Stage      ┆ Stage ┆ Record     │
# │ ---         ┆ ID          ┆ Time       ┆ ---        ┆   ┆ ---  ┆ Group      ┆ Order ┆ Type       │
# │ str         ┆ ---         ┆ ---        ┆ str        ┆   ┆ u64  ┆ ---        ┆ ---   ┆ ---        │
# │             ┆ str         ┆ datetime[μ ┆            ┆   ┆      ┆ cat        ┆ i32   ┆ str        │
# │             ┆             ┆ s]         ┆            ┆   ┆      ┆            ┆       ┆            │
# ╞═════════════╪═════════════╪════════════╪════════════╪═══╪══════╪════════════╪═══════╪════════════╡
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-17 ┆ Retention  ┆ … ┆ 1    ┆ Output     ┆ 3800  ┆ OUTPUT     │
# │ _466        ┆ 720831070   ┆ 18:21:40.2 ┆            ┆   ┆      ┆            ┆       ┆            │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-17 ┆ Retention  ┆ … ┆ 2    ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _466        ┆ 720831070   ┆ 18:21:40.2 ┆            ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-17 ┆ Retention  ┆ … ┆ 3    ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _466        ┆ 720831070   ┆ 18:21:40.2 ┆            ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-17 ┆ Retention  ┆ … ┆ 4    ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _466        ┆ 720831070   ┆ 18:21:40.2 ┆            ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-17 ┆ Retention  ┆ … ┆ 5    ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _466        ┆ 720831070   ┆ 18:21:40.2 ┆            ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ …           ┆ …           ┆ …          ┆ …          ┆ … ┆ …    ┆ …          ┆ …     ┆ …          │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-17 ┆ Acquisitio ┆ … ┆ 68   ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _466        ┆ 720831070   ┆ 18:21:40.2 ┆ n          ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-17 ┆ ActivateUs ┆ … ┆ 69   ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _466        ┆ 720831070   ┆ 18:21:40.2 ┆ e          ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-17 ┆ Retention  ┆ … ┆ 70   ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _466        ┆ 720831070   ┆ 18:21:40.2 ┆            ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-17 ┆ Retention  ┆ … ┆ 71   ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _466        ┆ 720831070   ┆ 18:21:40.2 ┆            ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# │ pySubjectID ┆ -8570391784 ┆ 2024-06-17 ┆ Retention  ┆ … ┆ 72   ┆ Arbitratio ┆ 10000 ┆ FILTERED_O │
# │ _466        ┆ 720831070   ┆ 18:21:40.2 ┆            ┆   ┆      ┆ n          ┆       ┆ UT         │
# │             ┆             ┆ 02300      ┆            ┆   ┆      ┆            ┆       ┆            │
# └─────────────┴─────────────┴────────────┴────────────┴───┴──────┴────────────┴───────┴────────────┘

# %% [markdown]
# ### Action Distribution
#
# Distribution of actions at the Arbitration stage. Helps identify action groups that rarely survive to Arbitration.

# %%
stage = "Arbitration"
scope_options = ["Issue", "Group", "Action"]
distribution_data = decision_data.get_distribution_data(stage, scope_options)
fig = decision_data.plot.distribution_as_treemap(
    df=distribution_data, stage=stage, scope_options=scope_options
)
fig.show()
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="9e8dda1a-03f2-4f15-bfc1-ae3221015b1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("9e8dda1a-03f2-4f15-bfc1-ae3221015b1e")) {                    Plotly.newPlot(                        "9e8dda1a-03f2-4f15-bfc1-ae3221015b1e",                        [{"branchvalues":"total","customdata":[["(?)"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["ActivateUse"],["ActivateUse"],["ActivateUse"],["ActivateUse"],["ActivateUse"],["ActivateUse"],["ActivateUse"],["Engagement"],["Engagement"],["Engagement"],["Engagement"],["Engagement"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Service"],["Service"],["Service"],["Service"],["Service"],["Service"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eDecisions=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003eIssue=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["All Actions Arbitration","All Actions Arbitration\u002fAcquisition\u002fLoans\u002fpyName_557","All Actions Arbitration\u002fAcquisition\u002fProactive\u002fpyName_168","All Actions Arbitration\u002fAcquisition\u002fProactive_1\u002fpyName_169","All Actions Arbitration\u002fAcquisition\u002fMortgage_1\u002fpyName_245","All Actions Arbitration\u002fAcquisition\u002fProactive\u002fpyName_47","All Actions Arbitration\u002fAcquisition\u002fProactive\u002fpyName_441","All Actions Arbitration\u ...

# %% [markdown]
# ### Global Sensitivity
#
# Shows the impact of each arbitration factor (Propensity, Value, Context Weight, Levers) on the final decision. Each bar represents how many decisions would change if that factor were removed. Ideally, Propensity should have the strongest influence.

# %%
decision_data.plot.sensitivity(win_rank=1)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="7bd4ab07-c36c-450b-a752-7d5db0c401c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7bd4ab07-c36c-450b-a752-7d5db0c401c5")) {                    Plotly.newPlot(                        "7bd4ab07-c36c-450b-a752-7d5db0c401c5",                        [{"customdata":{"dtype":"f8","bdata":"AAAAAADAUUAAAAAAAMBRQAAAAAAAAD5AAAAAAAAAPkAAAAAAAABEQAAAAAAAAERAAAAAAAAAPUAAAAAAAAA9QA==","shape":"4, 2"},"hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eInfluence: %{customdata[0]} decisions\u003cbr\u003eRelative: %{customdata[1]:.2f}%\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"i4","bdata":"RwAAAB4AAAAoAAAAHQAAAA=="},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"text":["71.0%","30.0%","40.0%","29.0%"],"textposition":"auto","x":{"dtype":"i4","bdata":"RwAAAB4AAAAoAAAAHQAAAA=="},"xaxis":"x","y":["Propensity","Value","Context Weights","Levers"],"yaxis":"y","type":"bar"}],                        {"template":{"layout":{"colorway":["#001F5F","#10A5AC","#F76923","#661D34","#86CAC6","#005154","#86CAC6","#5F67B9","#FFC836","#E63690","#AC1361","#63666F","#A7A9B4","#D0D1DB"],"hovermode":"closest"}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Decisions"},"ticksuffix":""},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"Prioritization Factor"},"autorange":"reversed","showticklabels":true,"automargin":true,"ticklabelposition":"outside"},"coloraxis":{"colorbar":{"title":{"text":"Influence"}},"colorscale":[[0.0,"rgb(165,0,38)"],[0.1,"rgb(215,48,39)"],[0.2,"rgb(244,109,67)"],[0.3,"rgb(253,174,97)"],[0.4,"rgb(254,224,139)"],[0.5,"rgb(255,255,191)"],[0.6,"rgb(217,239,139)"],[0.7,"rgb(166,217,106)"],[0.8,"rgb(102,189,99)"],[0.9,"rgb(26,152,80)"],[1.0,"rgb(0,104,55)"]],"cmin":0,"cmax":71,"showscale":false},"legend":{"tracegroupgap":0},"margin":{"t":60},"barmode":"relative","showlegend":false},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('7bd4ab07-c36c-450b-a752-7d5db0c401c5');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ### Wins and Losses in Arbitration

# %% [markdown]
# Distribution of wins and losses by Issue. The `level` parameter can be set to `"Group"` or `"Action"` for different granularity. Actions are classified as winning or losing based on `win_rank`.

# %%
decision_data.plot.global_winloss_distribution(level="Issue", win_rank=1)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="94a8205f-510b-46ba-a72c-14eec400f96f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("94a8205f-510b-46ba-a72c-14eec400f96f")) {                    Plotly.newPlot(                        "94a8205f-510b-46ba-a72c-14eec400f96f",                        [{"hovertemplate":"\u003cb\u003e%{label}\u003c\u002fb\u003e\u003cbr\u003e%{percent}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Retention","Acquisition","Service","Engagement","ActivateUse"],"marker":{"colors":["#661D34","#001F5F","#86CAC6","#F76923","#10A5AC"]},"textinfo":"label+percent","textposition":"auto","values":{"dtype":"f8","bdata":"XI\u002fC9Shc7z97FK5H4XqUPwAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA=="},"type":"pie","domain":{"x":[0.0,0.45],"y":[0.0,1.0]}},{"hovertemplate":"\u003cb\u003e%{label}\u003c\u002fb\u003e\u003cbr\u003e%{percent}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Retention","Acquisition","ActivateUse","Service","Engagement"],"marker":{"colors":["#661D34","#001F5F","#10A5AC","#86CAC6","#F76923"]},"textinfo":"label+percent","textposition":"auto","values":{"dtype":"f8","bdata":"K5DnOijZ4z9ggNP+1EzQP0RvaCjQdKw\u002fwsm4eYoHrD9OBSfj5imOPw=="},"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,1.0]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"e ...

# %% [markdown]
# ### Optionality Analysis
#
# Shows how many actions are available per customer at the Arbitration stage. Limited optionality reduces the ability to personalize. The bars show decision counts per number of available actions; the line shows average propensity of the top-ranked action. Average propensity should increase with more available actions.

# %%
decision_data.plot.propensity_vs_optionality(stage="Arbitration")
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="52e38618-389d-4f68-96dc-d59c100befdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("52e38618-389d-4f68-96dc-d59c100befdb")) {                    Plotly.newPlot(                        "52e38618-389d-4f68-96dc-d59c100befdb",                        [{"customdata":{"dtype":"f8","bdata":"AAAAvT7D3j9Co89Lvu3fPxlpcr9dVd8\u002fGqzK9u5J3z\u002ftI6nGHcXfPxyyCno9+t4\u002fqQJyPY0L3z88QQicm8\u002ffP+dkVkN3+t8\u002fOo3V4ji03z\u002fQ2Z9gJpbfP5VdHt+0UN8\u002fI08vuSKx3z\u002fwTnmlqgvcP8yCFNpv0d8\u002ffm3eX+zO3z9LC6opGITfP07oD1aSbd8\u002f7AwC2LGe3z\u002fgBSiNdqTfP9dx4U02cd8\u002f1kGF+Ba53z8AAAAAAAAAAA==","shape":"23, 1"},"hovertemplate":"Optionality = %{x}\u003cbr\u003eDecisions = %{y:.1f}%\u003cbr\u003eAvg Propensity = %{customdata[0]:.3%}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":["#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#001F5F","#cd001f"]},"name":"Optionality","x":{"dtype":"u1","bdata":"WFdWVFNSUVBPTk1MS0pJSEdGRURDQgA="},"y":{"dtype":"f8","bdata":"AAAAAAAA8D8AAAAAAADwPwAAAAAAAAhAAAAAAAAA8D8AAAAAAAAAQAAAAAAAAPA\u002fAAAAAAAACEAAAAAAAADwPwAAAAAAAPA\u002fAAAAAAAAAEAAAAAAAAAQQAAAAAAAAPA\u002fAAAAAAAAFEAAAAAAAAAgQAAAAAAAACBAAAAAAAAAIkABAAAAAAAsQAAAAAAAACRAAAAAAAAAIEAAAAAAAAAkQAAAAAAAAAhAAAAAAAAAEEAAAAAAAAAAAA=="},"type":"bar"},{"hovertemplate":"Optionality = %{x}\u003cbr\u003eAvg Propensity = %{y:.3%}\u003cextra\u003e\u003c\u002fextra\u003e","mode":"markers+lines","name":"Propensity","x":{"dtype":"u1","bdata":"WFdWVFNSUVBPTk1MS0pJSEdGRURDQgA="},"y":{"dtype":"f8","bdata":"AAAAvT7D3j9Co89Lvu3fPxlpcr9dVd8\u002fGqzK9u5J3z\u002ftI6nGHcXfPxyyCno9+t4\u002fqQJyPY0L3z88QQicm8\u002ffP+dkVkN3+t8\u002fOo3V4ji03z\u002fQ2Z9gJpbfP5VdHt+0UN8\u002fI08vuSKx3z\u002fwTnmlqgvcP8yCFNpv0d8\u002ffm3eX+zO3z9LC6opGITfP07oD1aSbd8\u002f7AwC2LGe3z\u002fgBSiNdqTfP9dx4U02cd8\u002f1kGF+Ba53z8AAAAAAAAAAA=="},"yaxis":"y2","type":"scatter","xaxis":"x"}],                        {"template":{"layout":{"colorway":["#001F5F","#10A5AC","#F76923","#661D34","#86CAC6","#005154","#86CAC6","#5F67B9","#FFC836","#E63690","#AC1361","#63666F","#A7A9B4","#D0D1DB"],"hovermode":"closest"}},"xaxis":{"anchor":"y","domain":[0.0,0.94],"title":{"text":"Number of Actions per Customer"}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"% of Decisions"},"ticksuffix":"%"},"yaxis2":{"anchor":"x","overlaying":"y","side":"right","title":{"text":"Propensity"},"tickformat":",.3%","showgrid":false}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('52e38618-389d-4f68-96dc-d59c100befdb');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ### Win/Loss Analysis

# %% [markdown]
# #### Win Analysis
# Select an action and see how often it wins and which actions it defeats.

# %%
win_rank = 1
selected_action = (
    decision_data.decision_data.filter(pl.col("Rank") == 1)
    .group_by("Action")
    .len()
    .sort("len", descending=True)
    .collect()
    .get_column("Action")
    .to_list()[1]
)
filter_statement = pl.col("Action") == selected_action

interactions_where_comparison_group_wins = (
    decision_data.get_winning_or_losing_interactions(
        group_filter=filter_statement,
        win=True,
    )
)

print(
    f"selected action '{selected_action}' wins(Rank{win_rank}) in {interactions_where_comparison_group_wins.collect().height} interactions."
)
# Out:
# selected action 'pyName_61' wins(Rank1) in 88 interactions.

# %% [markdown]
# Actions that lose to the selected action in arbitration.

# %%
# Losing actions in interactions where the selected action wins.
groupby_cols = ["Issue", "Group", "Action"]
winning_from = decision_data._winning_from(
    interactions=interactions_where_comparison_group_wins,
    win_rank=win_rank,
    groupby_cols=groupby_cols,
    top_k=20,
)

decision_data.plot.distribution_as_treemap(
    df=winning_from, stage="Arbitration", scope_options=groupby_cols
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="1d0c7967-bc87-490c-80b4-3db1604b621f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1d0c7967-bc87-490c-80b4-3db1604b621f")) {                    Plotly.newPlot(                        "1d0c7967-bc87-490c-80b4-3db1604b621f",                        [{"branchvalues":"total","customdata":[["(?)"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["Acquisition"],["ActivateUse"],["ActivateUse"],["ActivateUse"],["ActivateUse"],["ActivateUse"],["Engagement"],["Engagement"],["Engagement"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"],["Retention"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eDecisions=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003eIssue=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["All Actions Arbitration","All Actions Arbitration\u002fAcquisition\u002fCollections\u002fpyName_435","All Actions Arbitration\u002fAcquisition\u002fBilling\u002fpyName_57","All Actions Arbitration\u002fAcquisition\u002fRetailBank\u002fpyName_45","All Actions Arbitration\u002fAcquisition\u002fProactive\u002fpyName_464","All Actions Arbitration\u002fAcquisition\u002fLoans\u002fpyName_20","All Actions Arbitration\u002fAcquisition\u002fMortgage_1\u002fpyName_43","All Actions Arbitration\u002fAcquisition\u002fRetailBank","All Actions Arbitration\u002fAcquisition\u002fLoans","All Actions Arbitration\u002fAcquisition\u002fProactive","All Actions Arbitration\u002fAcquisition\u002fMortgage_1","All Actions Arbitration\u002fAcquisition\u002fCollections","All Actions Arbitration\u002fAcquisition\u002fBilling","All Actions Arbitration\u002fAcquisition","All Actions Arbitration\u002fActivateUse\u002fProactive_1\u002fpyName_362","All Actions Arbitration\u002fActivateUse\u002fMortgage\u002fpyName_605","All Actions Arbitration\u002fActivateUse\u002fProactive_1","All Actions Arbitration\u002fActivateUse\u002fMortgage","All Actions Arbitration\u002fActivateUse","All Actions Arbitration\u002fEngagement\u002fProactive_1\u002fpyName_242","All Actions Arbitration\u002fEngagement\u002fProactive_1","All Actions Arbitration\u002fEngagement","All Actions Arbitration\u002fRetention\u002fProactive\u002fpyName_223","All Actions Arbitration\u002fRetention\u002fProactive_1\u002fpyName_475","All Actions Arbitration\u002fRetention\u002fCreditCard\u002fpyName_437","All Actions Arbitration\u002fRetention\u002fProactive\u002fpyName_188","All Actions Arbitration\u002fRetention\u002fProactive_1\u002fpyName_450","All Actions Arbitration\u002fRetention\u002fProactive\u002fpyName_483","All Actions Arbitration\u002fRetention\u002fBilling_1\u002fpyName_117","All Actions Arbitration\u002fRetention\u002fProactive_1\u002fpyName_62","All Actions Arbitration\u002fRetention\u002fProactive_1\u002fpyName_172","All Actions Arbitration\u002fRetention\u002fRetailBank_1\u002fpyName_249","All Actions Arbitration\u002fRetention\u002fProactive_1\u002fpyName_266","All Actions Arbitration\u002fRetention\u002fProactive","All Actions Arbitration\u002fRetention\u002fCreditCard","All Actions Arbitration\u002fRetention\u002fProactive_1","All Actions Arbitration\u002fRetention\u002fBilling_1","All Actions Arbitration\u002fRetention\u002fRetailBank_1","All Actions Arbitration\u002fRetention"],"labels":["All Actions Arbitration","pyName_435","pyName_57","pyNam ...
#
# var gd = document.getElementById('1d0c7967-bc87-490c-80b4-3db1604b621f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer

# %% [markdown]
# #### Loss Analysis
# Actions that beat the selected action in arbitration.

# %%
interactions_where_comparison_group_loses = (
    decision_data.get_winning_or_losing_interactions(
        group_filter=filter_statement,
        win=False,
    )
)

print(
    f"selected action '{selected_action}' loses in {interactions_where_comparison_group_loses.collect().height} interactions."
)
# Winning actions in interactions where the selected action loses.
losing_to = decision_data._losing_to(
    interactions=interactions_where_comparison_group_loses,
    win_rank=win_rank,
    groupby_cols=groupby_cols,
    top_k=20,
)

decision_data.plot.distribution_as_treemap(
    df=losing_to, stage="Arbitration", scope_options=groupby_cols
)
# Out:
# selected action 'pyName_61' loses in 58 interactions.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="5cfc0b58-9811-4f13-b83a-92791daef70b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5cfc0b58-9811-4f13-b83a-92791daef70b")) {                    Plotly.newPlot(                        "5cfc0b58-9811-4f13-b83a-92791daef70b",                        [{"branchvalues":"total","customdata":[],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eDecisions=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003eIssue=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","ids":[],"labels":[],"marker":{"colors":[]},"name":"","parents":[],"values":[],"type":"treemap","root":{"color":"lightgrey"}}],                        {"template":{"layout":{"colorway":["#001F5F","#10A5AC","#F76923","#661D34","#86CAC6","#005154","#86CAC6","#5F67B9","#FFC836","#E63690","#AC1361","#63666F","#A7A9B4","#D0D1DB"],"hovermode":"closest"}},"legend":{"tracegroupgap":0},"margin":{"t":60}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('5cfc0b58-9811-4f13-b83a-92791daef70b');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# #### Sensitivity for Selected Action
# Change in win count when each prioritization factor is individually removed. Unlike the global sensitivity above, negative values are possible: a negative value means removing that factor would increase wins for the selected action (i.e., that factor is hurting it).

# %%
decision_data.plot.sensitivity(
    reference_group=pl.col("Action") == selected_action
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="494ace1a-363a-47ce-a045-b400d907f55e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("494ace1a-363a-47ce-a045-b400d907f55e")) {                    Plotly.newPlot(                        "494ace1a-363a-47ce-a045-b400d907f55e",                        [{"customdata":{"dtype":"f8","bdata":"AAAAAAAANEB7FK5H4apQQAAAAAAAABhAAAAAAAAANEAAAAAAAAAAQK5H4XoUrhpAAAAAAAAALsAAAAAAAABJwA==","shape":"4, 2"},"hovertemplate":"\u003cb\u003e%{y}\u003c\u002fb\u003e\u003cbr\u003eInfluence: %{customdata[0]} decisions\u003cbr\u003eRelative: %{customdata[1]:.2f}%\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":{"dtype":"i4","bdata":"FAAAAAYAAAACAAAA8f\u002f\u002f\u002fw=="},"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","orientation":"h","showlegend":false,"text":["66.67%","20.0%","6.67%","-50.0%"],"textposition":"auto","x":{"dtype":"i4","bdata":"FAAAAAYAAAACAAAA8f\u002f\u002f\u002fw=="},"xaxis":"x","y":["Propensity","Value","Context Weights","Levers"],"yaxis":"y","type":"bar"}],                        {"template":{"layout":{"colorway":["#001F5F","#10A5AC","#F76923","#661D34","#86CAC6","#005154","#86CAC6","#5F67B9","#FFC836","#E63690","#AC1361","#63666F","#A7A9B4","#D0D1DB"],"hovermode":"closest"}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Decisions"},"ticksuffix":""},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"Prioritization Factor"},"autorange":"reversed","showticklabels":true,"automargin":true,"ticklabelposition":"outside"},"coloraxis":{"colorbar":{"title":{"text":"Influence"}},"colorscale":[[0.0,"rgb(165,0,38)"],[0.1,"rgb(215,48,39)"],[0.2,"rgb(244,109,67)"],[0.3,"rgb(253,174,97)"],[0.4,"rgb(254,224,139)"],[0.5,"rgb(255,255,191)"],[0.6,"rgb(217,239,139)"],[0.7,"rgb(166,217,106)"],[0.8,"rgb(102,189,99)"],[0.9,"rgb(26,152,80)"],[1.0,"rgb(0,104,55)"]],"cmin":0,"cmax":20,"showscale":false},"legend":{"tracegroupgap":0},"margin":{"t":60},"barmode":"relative","showlegend":false},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('494ace1a-363a-47ce-a045-b400d907f55e');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# #### Prioritization Factor Distributions
#
# Box plots comparing the arbitration factor distributions of the selected action vs competitors in the same interactions.

# %%
fig, warning_message = decision_data.plot.prio_factor_boxplots(
    reference=pl.col("Action") == selected_action,
)
if warning_message:
    print(warning_message)
else:
    fig.show()
# Out:
# Comparison group never survives to Arbitration

# %% [markdown]
# #### Rank Distribution
#
# Distribution of the prioritization rank for the selected action. Low ranks indicate the action is not often winning.

# %%
decision_data.plot.rank_boxplot(
    reference=pl.col("Action") == selected_action,
)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="fc8994c1-ae35-43cf-b481-16db04d64bc0" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fc8994c1-ae35-43cf-b481-16db04d64bc0")) {                    Plotly.newPlot(                        "fc8994c1-ae35-43cf-b481-16db04d64bc0",                        [{"alignmentgroup":"True","hovertemplate":"Rank=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#001F5F"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":{"dtype":"u1","bdata":"AgQDAgYCAgEBAQIBBQEBAgIBAgMEAwIBAScBAQIEBAEBAgEBBAECBAQCAgICAQMCAgIBAQEBBQEBAQQDAgMCBAICAQMGAQIFAgEDAQICAQIHAgEDBgIDCA=="},"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"layout":{"colorway":["#001F5F","#10A5AC","#F76923","#661D34","#86CAC6","#005154","#86CAC6","#5F67B9","#FFC836","#E63690","#AC1361","#63666F","#A7A9B4","#D0D1DB"],"hovermode":"closest"}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Rank"}},"yaxis":{"anchor":"x","domain":[0.0,1.0]},"legend":{"tracegroupgap":0},"margin":{"t":60},"boxmode":"group","height":300},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('fc8994c1-ae35-43cf-b481-16db04d64bc0');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>
